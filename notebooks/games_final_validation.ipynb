# %%
import pandas as pd
matched = pd.read_csv('../data/processed/games_final.csv')
matched['GAME_DATE'] = pd.to_datetime(matched['GAME_DATE'])

# %%
print("Duplicates GAME_ID:", matched['GAME_ID'].duplicated().sum())
print("Date range:", matched['GAME_DATE'].min(), "-", matched['GAME_DATE'].max())
print("Number of unique seasons:", matched['SEASON_ID'].nunique())
print(matched['SEASON_ID'].value_counts().sort_index())
# Out:
# Duplicates GAME_ID: 0
# Date range: 2020-12-22 00:00:00 - 2026-04-12 00:00:00
# Number of unique seasons: 6
# SEASON_ID
# 22020    1080
# 22021    1230
# 22022    1230
# 22023    1230
# 22024    1230
# 22025    1230
# Name: count, dtype: int64

# %%
missing = matched.isna().sum()
missing = missing[missing > 0].sort_values(ascending=False)
print(missing)
# Out:
# HOME_matchup_pts_5               435
# AWAY_matchup_pts_5               435
# HOME_matchup_reb_5               435
# AWAY_matchup_reb_5               435
# HOME_matchup_ast_5               435
#                                 ...
# HOME_rolling_fg3_pct_10           89
# HOME_rolling_def_rating_5         89
# HOME_rolling_net_rating_5         89
# HOME_rolling_net_rating_adj_5     89
# HOME_rolling_poss_5               89
# Length: 87, dtype: int64

# %%
print(len(missing))  # ile kolumn ma jakiekolwiek braki
print(missing)  # bez cięcia, całość
# Out:
# 87
# HOME_matchup_pts_5               435
# AWAY_matchup_pts_5               435
# HOME_matchup_reb_5               435
# AWAY_matchup_reb_5               435
# HOME_matchup_ast_5               435
#                                 ...
# HOME_rolling_fg3_pct_10           89
# HOME_rolling_def_rating_5         89
# HOME_rolling_net_rating_5         89
# HOME_rolling_net_rating_adj_5     89
# HOME_rolling_poss_5               89
# Length: 87, dtype: int64

# %%
problem_row = matched[matched['AWAY_rolling_pts_5'].isna() & matched['HOME_rest_days'].notna()]
print(problem_row[['GAME_ID', 'GAME_DATE', 'HOME_TEAM_ABBR', 'AWAY_TEAM_ABBR']])
# Out:
#        GAME_ID  GAME_DATE HOME_TEAM_ABBR AWAY_TEAM_ABBR
# 20    22000022 2020-12-26            CHA            OKC
# 27    22000029 2020-12-26            POR            HOU
# 1095  22100016 2021-10-21            GSW            LAC
# 2324  22200015 2022-10-20            PHI            MIL
# 2325  22200016 2022-10-20            LAL            LAC
# 6015  22500006 2025-10-23            GSW            DEN

# %%
print([c for c in matched.columns if 'PTS' in c.upper() or 'REB' in c.upper()])
# Out:
# ['HOME_matchup_pts_5', 'AWAY_matchup_pts_5', 'HOME_matchup_reb_5', 'AWAY_matchup_reb_5', 'HOME_rolling_pts_5', 'HOME_rolling_reb_5', 'HOME_rolling_pts_10', 'HOME_rolling_reb_10', 'AWAY_rolling_pts_5', 'AWAY_rolling_reb_5', 'AWAY_rolling_pts_10', 'AWAY_rolling_reb_10']

# %%
print(matched[['HOME_elo', 'AWAY_elo']].describe())
print(matched[['HOME_rest_days', 'AWAY_rest_days']].describe())
print(matched[['HOME_streak', 'AWAY_streak']].describe())
# Out:
#           HOME_elo     AWAY_elo
# count  7230.000000  7230.000000
# mean   1500.131524  1499.915158
# std      96.210025    96.784781
# min    1221.970605  1215.228739
# 25%    1443.950865  1443.004041
# 50%    1510.107073  1509.598973
# 75%    1565.357439  1566.182241
# max    1795.544857  1799.702009
#        HOME_rest_days  AWAY_rest_days
# count     7141.000000     7139.000000
# mean         2.145918        2.072839
# std          1.000417        0.976476
# min          1.000000        1.000000
# 25%          2.000000        2.000000
# 50%          2.000000        2.000000
# 75%          2.000000        2.000000
# max          9.000000       13.000000
#        HOME_streak  AWAY_streak
# count  7230.000000  7230.000000
# mean     -0.056293    -0.103734
# std       3.236816     3.200632
# min     -28.000000   -27.000000
# 25%      -2.000000    -2.000000
# 50%       0.000000     0.000000
# 75%       2.000000     2.000000
# max      17.000000    18.000000

# %%
print(matched['home_win'].value_counts(normalize=True))
# Out:
# home_win
# 1    0.551729
# 0    0.448271
# Name: proportion, dtype: float64

# %%
matched.sample(5, random_state=42).T
# Out:
#                                          1595                 6958  \
# GAME_ID                              22100526             22500931
# GAME_DATE                 2021-12-30 00:00:00  2026-03-09 00:00:00
# SEASON_ID                               22021                22025
# HOME_TEAM_ID                       1610612753           1610612739
# HOME_TEAM_ABBR                            ORL                  CLE
# ...                                       ...                  ...
# off_rating_diff_10                  -6.519658             8.454112
# def_rating_diff_10                   4.525922            -4.962041
# poss_diff_10                           -2.676               -4.878
# venue_net_rating_diff_10           -16.548983             4.295631
# is_early_season                             0                    0
#
#                                          3187                 2154  \
# GAME_ID                              22200879             22101076
# GAME_DATE                 2023-02-15 00:00:00  2022-03-21 00:00:00
# SEASON_ID                               22022                22021
# HOME_TEAM_ID                       1610612763           1610612741
# HOME_TEAM_ABBR                            MEM                  CHI
# ...                                       ...                  ...
# off_rating_diff_10                  -9.002644            -4.303162
# def_rating_diff_10                  -7.767707             6.920308
# poss_diff_10                            0.884                2.724
# venue_net_rating_diff_10              8.77503             0.262249
# is_early_season                             0                    0
#
#                                          4003
# GAME_ID                              22300434
# GAME_DATE                 2023-12-29 00:00:00
# SEASON_ID                               22023
# HOME_TEAM_ID                       1610612745
# HOME_TEAM_ABBR                            HOU
# ...                                       ...
# off_rating_diff_10                  -9.593969
# def_rating_diff_10                   7.679358
# poss_diff_10                            0.938
# venue_net_rating_diff_10            -1.837119
# is_early_season                             0
#
# [122 rows x 5 columns]
