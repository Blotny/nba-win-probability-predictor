# %%
import pandas as pd

df = pd.read_csv('../data/raw/games.csv')

print(df.shape)
print(df.describe())
print(df.head())
# Out:
# (14460, 28)
#           SEASON_ID       TEAM_ID       GAME_ID           MIN           PTS  \
# count  14460.000000  1.446000e+04  1.446000e+04  14460.000000  14460.000000
# mean   22022.551867  1.610613e+09  2.225579e+07    241.490041    113.535546
# std        1.686718  8.655741e+00  1.686891e+05      6.513535     12.709174
# min    22020.000000  1.610613e+09  2.200000e+07    236.000000     66.000000
# 25%    22021.000000  1.610613e+09  2.210073e+07    240.000000    105.000000
# 50%    22023.000000  1.610613e+09  2.230008e+07    240.000000    113.000000
# 75%    22024.000000  1.610613e+09  2.240065e+07    241.000000    122.000000
# max    22025.000000  1.610613e+09  2.250123e+07    316.000000    176.000000
#
#                 FGM           FGA        FG_PCT          FG3M          FG3A  \
# count  14460.000000  14460.000000  14460.000000  14460.000000  14460.000000
# mean      41.614246     88.679945      0.470197     12.861964     35.636307
# ...
